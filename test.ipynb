# %%
# Out:
#        animal session  trial  offer_prob  slp_accept         quit  \
# 0      RRM026  Day151      1         0.0         1.0          NaN
# 1      RRM026  Day151      2        20.0         1.0          NaN
# 2      RRM026  Day151      3         0.0         1.0          NaN
# 3      RRM026  Day151      4        80.0         1.0          NaN
# 4      RRM026  Day151      5        20.0         1.0          NaN
# ...       ...     ...    ...         ...         ...          ...
# 12486  RRM036  Day176    127        20.0         0.0  3542.927782
# 12487  RRM036  Day176    128       100.0         1.0          NaN
# 12488  RRM036  Day176    129       100.0         1.0          NaN
# 12489  RRM036  Day176    130        80.0         1.0          NaN
# 12490  RRM036  Day176    131        20.0         0.0  3627.858650
#
#        slp_T_Entry_time  slp_choice_time  reward  restaurant
# 0             46.082765        46.216269       0           1
# ...
